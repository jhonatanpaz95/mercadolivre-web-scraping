# %%
import requests as req
from requests.exceptions import HTTPError
from bs4 import BeautifulSoup

# %%
# link para download
link = 'https://www.mercadolivre.com.br/mais-vendidos/MLB1051#origin=home'

# função para requisição do link
def requisicao(url: str, headers:dict) -> str:

    try:
        resposta = req.get(url, headers=headers)
        resposta.raise_for_status()
    except HTTPError as exc:
        print(exc)
    except Exception  as e:
        print(e)
    else:
        return resposta.text

# %%
#headers para parametro
HEADERS = {
    'User-Agent':'Mozila/5.0',
    'Accept-Language': 'en-US,en;q=0.5'
}

#dowload da pagina
extracao = requisicao(link, headers=HEADERS)

print(extracao)
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR">
# ...

# %%
#selecionando somente o html da pagina
pagina_mercadolivre = BeautifulSoup(extracao, 'html.parser')<div class="ui-search-layout--grid__grid">
print(pagina_mercadolivre)
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# ...

# %%
produtos = pagina_mercadolivre.find('div', {'class':'ui-search-layout--grid__grid'})
print(produtos)
# Out:
# <div class="ui-search-layout--grid__grid"><div class="ui-recommendations-card ui-recommendations-card--vertical show-original-price __item"><div class="ui-recommendations-card__image-container"><img alt="" class="ui-recommendations-card__image" decoding="sync" fetchpriority="high" height="224px" src="https://http2.mlstatic.com/D_Q_NP_668543-MLA75547177771_042024-AB.jpg" srcset="https://http2.mlstatic.com/D_Q_NP_668543-MLA75547177771_042024-AB.jpg, https://http2.mlstatic.com/D_Q_NP_2X_668543-MLA75547177771_042024-AB.jpg 2x" width="224px"/></div><div class="ui-recommendations-card__content-and-hidden"><div class="ui-recommendations-card__content"><div class="ui-recommendations-card__highlight-deal"><span class="ui-recommendations-card__pill" style="font-size:12px;font-weight:600;font-style:normal;color:#FFFFFF;background:#FF7733">1º MAIS VENDIDO</span></div><p class="ui-recommendations-card__title"><a class="ui-recommendations-card__link" href="https://www.mercadolivre.com.br/samsung-g
# ...
